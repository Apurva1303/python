# %%
18/06/2026

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.shape
# Out:
# (10, 5)

# %%
df.columns
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   roll    10 non-null     int64
#  1   name    10 non-null     object
#  2   class   10 non-null     object
#  3   marks   10 non-null     float64
#  4   age     10 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
df.dtypes
# Out:
# roll       int64
# name      object
# class     object
# marks    float64
# age        int64
# dtype: object

# %%
#this returns the values from the 1st index in a tabel
df.head()
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20

# %%
df.head(7)
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19

# %%
#this returns the values from the last index in a tabel
    df.tail()
# Out:
#    roll    name class  marks  age
# 5     6  ayesha    BE  49.55   20
# 6     7    amar    BE  65.34   19
# 7     8   amita    BE  68.33   23
# 8     9    amol    TE  56.75   20
# 9    10   anmol    BE  78.66   21

# %%
df.tail(3)
# Out:
#    roll   name class  marks  age
# 7     8  amita    BE  68.33   23
# 8     9   amol    TE  56.75   20
# 9    10  anmol    BE  78.66   21

# %%
df.values
# Out:
# array([[1, 'anil', 'TE', 56.77, 22],
#        [2, 'amit', 'TE', 59.77, 21],
#        [3, 'aniket', 'BE', 76.88, 19],
#        [4, 'ajinkya', 'TE', 69.66, 20],
#        [5, 'asha', 'TE', 63.28, 20],
#        [6, 'ayesha', 'BE', 49.55, 20],
#        [7, 'amar', 'BE', 65.34, 19],
#        [8, 'amita', 'BE', 68.33, 23],
#        [9, 'amol', 'TE', 56.75, 20],
#        [10, 'anmol', 'BE', 78.66, 21]], dtype=object)

# %%
df.T
# Out:
#            0      1       2        3      4       5      6      7      8  \
# roll       1      2       3        4      5       6      7      8      9
# name    anil   amit  aniket  ajinkya   asha  ayesha   amar  amita   amol
# class     TE     TE      BE       TE     TE      BE     BE     BE     TE
# marks  56.77  59.77   76.88    69.66  63.28   49.55  65.34  68.33  56.75
# age       22     21      19       20     20      20     19     23     20
#
#            9
# roll      10
# name   anmol
# class     BE
# marks  78.66
# age       21

# %%
#slicing

# %%
# two options
# 1 --> index based --iloc
#2 --->coloumn based --

# %%
df.iloc[1:4,1:4]
# Out:
#       name class  marks
# 1     amit    TE  59.77
# 2   aniket    BE  76.88
# 3  ajinkya    TE  69.66

# %%
df.iloc[2:5,2:6]
# Out:
#   class  marks  age
# 2    BE  76.88   19
# 3    TE  69.66   20
# 4    TE  63.28   20

# %%
df.iloc[1:5,[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28

# %%
df.iloc[[1,2,3,4,6],[0,1,3]]
# Out:
#    roll     name  marks
# 1     2     amit  59.77
# 2     3   aniket  76.88
# 3     4  ajinkya  69.66
# 4     5     asha  63.28
# 6     7     amar  65.34

# %%
df.iloc[5,1]='geet'
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df.iloc[9:10,4:9]
# Out:
#    age
# 9   21

# %%
df.iloc[8:9,3:8]
# Out:
#    marks  age
# 8  56.75   20

# %%
# loc

# %%
df.loc[2:5,'name']
# Out:
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# Name: name, dtype: object

# %%
df.loc[2:5,['name','class']]
# Out:
#       name class
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE

# %%
df.loc[:,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df.loc[0:9,'name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df['name']
# Out:
# 0       anil
# 1       amit
# 2     aniket
# 3    ajinkya
# 4       asha
# 5       geet
# 6       amar
# 7      amita
# 8       amol
# 9      anmol
# Name: name, dtype: object

# %%
df[['name','class']]
# Out:
#       name class
# 0     anil    TE
# 1     amit    TE
# 2   aniket    BE
# 3  ajinkya    TE
# 4     asha    TE
# 5     geet    BE
# 6     amar    BE
# 7    amita    BE
# 8     amol    TE
# 9    anmol    BE

# %%
#methods on columns/series

# %%
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6     geet    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
df['name'].str.upper()
# Out:
# 0       ANIL
# 1       AMIT
# 2     ANIKET
# 3    AJINKYA
# 4       ASHA
# 5       GEET
# 6       AMAR
# 7      AMITA
# 8       AMOL
# 9      ANMOL
# Name: name, dtype: object

# %%
df['class'].str.lower()
# Out:
# 0    te
# 1    te
# 2    be
# 3    te
# 4    te
# 5    be
# 6    be
# 7    be
# 8    te
# 9    be
# Name: class, dtype: object

# %%
gender =['m','m','m','m','f','f','m','m','m','m']

# %%
df['gender']=gender

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0     1     anil    TE  56.77   22      m
# 1     2     amit    TE  59.77   21      m
# 2     3   aniket    BE  76.88   19      m
# 3     4  ajinkya    TE  69.66   20      m
# 4     5     asha    TE  63.28   20      f
# 5     6     geet    BE  49.55   20      f
# 6     7     amar    BE  65.34   19      m
# 7     8    amita    BE  68.33   23      m
# 8     9     amol    TE  56.75   20      m
# 9    10    anmol    BE  78.66   21      m

# %%
df['roll']=df['roll']+100

# %%
df
# Out:
#    roll     name class  marks  age gender
# 0   101     anil    TE  56.77   22      m
# 1   102     amit    TE  59.77   21      m
# 2   103   aniket    BE  76.88   19      m
# 3   104  ajinkya    TE  69.66   20      m
# 4   105     asha    TE  63.28   20      f
# 5   106     geet    BE  49.55   20      f
# 6   107     amar    BE  65.34   19      m
# 7   108    amita    BE  68.33   23      m
# 8   109     amol    TE  56.75   20      m
# 9   110    anmol    BE  78.66   21      m

# %%
#add a new column cgp
#values sholud = marks/10+1.5

# %%
df['cgp']=df['marks']/10+1.5

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 0   101     anil    TE  56.77   22      m  7.177  7.177
# 1   102     amit    TE  59.77   21      m  7.477  7.477
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466
# 4   105     asha    TE  63.28   20      f  7.828  7.828
# 5   106     geet    BE  49.55   20      f  6.455  6.455
# 6   107     amar    BE  65.34   19      m  8.034  8.034
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 8   109     amol    TE  56.75   20      m  7.175  7.175
# 9   110    anmol    BE  78.66   21      m  9.366  9.366

# %%
df.sort_values(by='name')
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466
# 6   107     amar    BE  65.34   19      m  8.034  8.034
# 1   102     amit    TE  59.77   21      m  7.477  7.477
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 8   109     amol    TE  56.75   20      m  7.175  7.175
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 0   101     anil    TE  56.77   22      m  7.177  7.177
# 9   110    anmol    BE  78.66   21      m  9.366  9.366
# 4   105     asha    TE  63.28   20      f  7.828  7.828
# 5   106     geet    BE  49.55   20      f  6.455  6.455

# %%
df
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 0   101     anil    TE  56.77   22      m  7.177  7.177
# 1   102     amit    TE  59.77   21      m  7.477  7.477
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466
# 4   105     asha    TE  63.28   20      f  7.828  7.828
# 5   106     geet    BE  49.55   20      f  6.455  6.455
# 6   107     amar    BE  65.34   19      m  8.034  8.034
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 8   109     amol    TE  56.75   20      m  7.175  7.175
# 9   110    anmol    BE  78.66   21      m  9.366  9.366

# %%
df.sort_values(by='marks')
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 5   106     geet    BE  49.55   20      f  6.455  6.455
# 8   109     amol    TE  56.75   20      m  7.175  7.175
# 0   101     anil    TE  56.77   22      m  7.177  7.177
# 1   102     amit    TE  59.77   21      m  7.477  7.477
# 4   105     asha    TE  63.28   20      f  7.828  7.828
# 6   107     amar    BE  65.34   19      m  8.034  8.034
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 9   110    anmol    BE  78.66   21      m  9.366  9.366

# %%
#sort by class and then marks simultaneously and check the result

# %%
df.sort_values(by=['class','marks'])
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 5   106     geet    BE  49.55   20      f  6.455  6.455
# 6   107     amar    BE  65.34   19      m  8.034  8.034
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 9   110    anmol    BE  78.66   21      m  9.366  9.366
# 8   109     amol    TE  56.75   20      m  7.175  7.175
# 0   101     anil    TE  56.77   22      m  7.177  7.177
# 1   102     amit    TE  59.77   21      m  7.477  7.477
# 4   105     asha    TE  63.28   20      f  7.828  7.828
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466

# %%
df['marks'].mean()
# Out:
# np.float64(64.499)

# %%
df['marks'].max()
# Out:
# 78.66

# %%
df.describe()
# Out:
#             roll      marks        age       cgpc        cgp
# count   10.00000  10.000000  10.000000  10.000000  10.000000
# mean   105.50000  64.499000  20.500000   7.949900   7.949900
# std      3.02765   9.207179   1.269296   0.920718   0.920718
# min    101.00000  49.550000  19.000000   6.455000   6.455000
# 25%    103.25000  57.520000  20.000000   7.252000   7.252000
# 50%    105.50000  64.310000  20.000000   7.931000   7.931000
# 75%    107.75000  69.327500  21.000000   8.432750   8.432750
# max    110.00000  78.660000  23.000000   9.366000   9.366000

# %%
#groupby

# %%
gr=df.groupby('class')

# %%
gr.groups
# Out:
# {'BE': [2, 5, 6, 7, 9], 'TE': [0, 1, 3, 4, 8]}

# %%
gr.get_group('BE')
# Out:
#    roll    name class  marks  age gender   cgpc    cgp
# 2   103  aniket    BE  76.88   19      m  9.188  9.188
# 5   106    geet    BE  49.55   20      f  6.455  6.455
# 6   107    amar    BE  65.34   19      m  8.034  8.034
# 7   108   amita    BE  68.33   23      m  8.333  8.333
# 9   110   anmol    BE  78.66   21      m  9.366  9.366

# %%
gr.min()
# Out:
#        roll     name  marks  age gender   cgpc    cgp
# class
# BE      103     amar  49.55   19      f  6.455  6.455
# TE      101  ajinkya  56.75   20      f  7.175  7.175

# %%
gr['marks'].mean()
# Out:
# class
# BE    67.752
# TE    61.246
# Name: marks, dtype: float64

# %%
df['marks']>60
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: marks, dtype: bool

# %%
df[df['marks']>60]
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466
# 4   105     asha    TE  63.28   20      f  7.828  7.828
# 6   107     amar    BE  65.34   19      m  8.034  8.034
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 9   110    anmol    BE  78.66   21      m  9.366  9.366

# %%
#filter the data of those student --> marks>60 and belongs to BC class

# %%
filtered_df = df[(df["marks"] > 60) & (df["class"] == "BE")]
filtered_df
# Out:
#    roll    name class  marks  age gender   cgpc    cgp
# 2   103  aniket    BE  76.88   19      m  9.188  9.188
# 6   107    amar    BE  65.34   19      m  8.034  8.034
# 7   108   amita    BE  68.33   23      m  8.333  8.333
# 9   110   anmol    BE  78.66   21      m  9.366  9.366

# %%
#drop--> drop column and rows

# %%
df.drop(4)
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 0   101     anil    TE  56.77   22      m  7.177  7.177
# 1   102     amit    TE  59.77   21      m  7.477  7.477
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466
# 5   106     geet    BE  49.55   20      f  6.455  6.455
# 6   107     amar    BE  65.34   19      m  8.034  8.034
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 8   109     amol    TE  56.75   20      m  7.175  7.175
# 9   110    anmol    BE  78.66   21      m  9.366  9.366

# %%
df.drop([6,8])
# Out:
#    roll     name class  marks  age gender   cgpc    cgp
# 0   101     anil    TE  56.77   22      m  7.177  7.177
# 1   102     amit    TE  59.77   21      m  7.477  7.477
# 2   103   aniket    BE  76.88   19      m  9.188  9.188
# 3   104  ajinkya    TE  69.66   20      m  8.466  8.466
# 4   105     asha    TE  63.28   20      f  7.828  7.828
# 5   106     geet    BE  49.55   20      f  6.455  6.455
# 7   108    amita    BE  68.33   23      m  8.333  8.333
# 9   110    anmol    BE  78.66   21      m  9.366  9.366

# %%
#drop name column

# %%
df.drop('name',axis=1)
# Out:
#    roll class  marks  age gender   cgpc    cgp
# 0   101    TE  56.77   22      m  7.177  7.177
# 1   102    TE  59.77   21      m  7.477  7.477
# 2   103    BE  76.88   19      m  9.188  9.188
# 3   104    TE  69.66   20      m  8.466  8.466
# 4   105    TE  63.28   20      f  7.828  7.828
# 5   106    BE  49.55   20      f  6.455  6.455
# 6   107    BE  65.34   19      m  8.034  8.034
# 7   108    BE  68.33   23      m  8.333  8.333
# 8   109    TE  56.75   20      m  7.175  7.175
# 9   110    BE  78.66   21      m  9.366  9.366

# %%
df.drop('age',axis=1)
# Out:
#    roll     name class  marks gender   cgpc    cgp
# 0   101     anil    TE  56.77      m  7.177  7.177
# 1   102     amit    TE  59.77      m  7.477  7.477
# 2   103   aniket    BE  76.88      m  9.188  9.188
# 3   104  ajinkya    TE  69.66      m  8.466  8.466
# 4   105     asha    TE  63.28      f  7.828  7.828
# 5   106     geet    BE  49.55      f  6.455  6.455
# 6   107     amar    BE  65.34      m  8.034  8.034
# 7   108    amita    BE  68.33      m  8.333  8.333
# 8   109     amol    TE  56.75      m  7.175  7.175
# 9   110    anmol    BE  78.66      m  9.366  9.366

# %%
df.drop(3)
# Out:
#    roll    name class  marks  age gender   cgpc    cgp
# 0   101    anil    TE  56.77   22      m  7.177  7.177
# 1   102    amit    TE  59.77   21      m  7.477  7.477
# 2   103  aniket    BE  76.88   19      m  9.188  9.188
# 4   105    asha    TE  63.28   20      f  7.828  7.828
# 5   106    geet    BE  49.55   20      f  6.455  6.455
# 6   107    amar    BE  65.34   19      m  8.034  8.034
# 7   108   amita    BE  68.33   23      m  8.333  8.333
# 8   109    amol    TE  56.75   20      m  7.175  7.175
# 9   110   anmol    BE  78.66   21      m  9.366  9.366

# %%
#drop name and class

# %%
df.drop(['name','class'],axis=1)
# Out:
#    roll  marks  age gender   cgpc    cgp
# 0   101  56.77   22      m  7.177  7.177
# 1   102  59.77   21      m  7.477  7.477
# 2   103  76.88   19      m  9.188  9.188
# 3   104  69.66   20      m  8.466  8.466
# 4   105  63.28   20      f  7.828  7.828
# 5   106  49.55   20      f  6.455  6.455
# 6   107  65.34   19      m  8.034  8.034
# 7   108  68.33   23      m  8.333  8.333
# 8   109  56.75   20      m  7.175  7.175
# 9   110  78.66   21      m  9.366  9.366

# %%
df.drop(['gender','cgp'],axis=1,inplace=True)

# %%
df
# Out:
#    roll     name class  marks  age   cgpc
# 0   101     anil    TE  56.77   22  7.177
# 1   102     amit    TE  59.77   21  7.477
# 2   103   aniket    BE  76.88   19  9.188
# 3   104  ajinkya    TE  69.66   20  8.466
# 4   105     asha    TE  63.28   20  7.828
# 5   106     geet    BE  49.55   20  6.455
# 6   107     amar    BE  65.34   19  8.034
# 7   108    amita    BE  68.33   23  8.333
# 8   109     amol    TE  56.75   20  7.175
# 9   110    anmol    BE  78.66   21  9.366

# %%
#create a dataframe newdf
#columns-->roll,gender,cgp
#roll column will hav the same values as that of in the df dataframe

# %%
newdf=pd.DataFrame({
    'roll':df['roll'],
    'gender':gender,
    'cgp':df['marks']/10+1.5
})

# %%
newdf
# Out:
#    roll gender    cgp
# 0   101      m  7.177
# 1   102      m  7.477
# 2   103      m  9.188
# 3   104      m  8.466
# 4   105      f  7.828
# 5   106      f  6.455
# 6   107      m  8.034
# 7   108      m  8.333
# 8   109      m  7.175
# 9   110      m  9.366

# %%
pd.merge(df,newdf)
# Out:
#    roll     name class  marks  age   cgpc gender    cgp
# 0   101     anil    TE  56.77   22  7.177      m  7.177
# 1   102     amit    TE  59.77   21  7.477      m  7.477
# 2   103   aniket    BE  76.88   19  9.188      m  9.188
# 3   104  ajinkya    TE  69.66   20  8.466      m  8.466
# 4   105     asha    TE  63.28   20  7.828      f  7.828
# 5   106     geet    BE  49.55   20  6.455      f  6.455
# 6   107     amar    BE  65.34   19  8.034      m  8.034
# 7   108    amita    BE  68.33   23  8.333      m  8.333
# 8   109     amol    TE  56.75   20  7.175      m  7.175
# 9   110    anmol    BE  78.66   21  9.366      m  9.366

# %%
#concat

# %%
#lod student5.csv

# %%
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
newdf=pd.read_csv('student5.csv')

# %%
newdf
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20

# %%
pd.concat([df,newdf],ignore_index=True)
# Out:
#    roll     name class  marks  age
# 0     1   surbhi    TE  67.44   23
# 1     2    sujay    TE  74.12   22
# 2     3  subhash    BE  82.44   21
# 3     4   sachin    TE  59.33   21
# 4     5  shalini    TE  63.45   20
# 5     1   surbhi    TE  67.44   23
# 6     2    sujay    TE  74.12   22
# 7     3  subhash    BE  82.44   21
# 8     4   sachin    TE  59.33   21
# 9     5  shalini    TE  63.45   20

# %%
f=df[(df['marks']>60)&(df['class']=='BE')]

# %%
f.to_csv('op.csv',index=False)

# %%
f
# Out:
#    roll     name class  marks  age
# 2     3  subhash    BE  82.44   21
