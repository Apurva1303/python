# %%
print("Hello")
# Out:
# Hello

# %%
#above->A,
#below->b
#delete->x

# %% [markdown]
# Identifiers
# ===

# %%
num=56

# %%
num1=8

# %%
name="riya"
name
# Out:
# 'riya'

# %%
rate=5
rate
# Out:
# 5

# %%
l=[3]
type(l)
# Out:
# list

# %%
num=10

# %%
num2=20.54

# %%
type(num)
# Out:
# int

# %%
name="Apurva"
name
# Out:
# 'Apurva'

# %%
type(name)
# Out:
# str

# %%
send="i like python programming"
send
# Out:
# 'i like python programming'

# %%
sent = "I like 'Python' Programming"
print(sent)
# Out:
# I like 'Python' Programming

# %%
a = 3
b = 5
z = a + b
print(z)
# Out:
# 8

# %%
a = 3; b = 5; z = a + b; print(z);
# Out:
# 8

# %%
a, b, c = 23, 56, "ok"

# %%
a
# Out:
# 23

# %%
b
# Out:
# 56

# %%
c
# Out:
# 'ok'

# %%
#float
num =23e4

# %%
type(num)
# Out:
# float

# %%
num
# Out:
# 230000.0
