# %%
num=int(input("enter 1st no."))
if num > 5:
    print('yes')
else:
    print('no')
# Out:
# enter 1st no. 1
# no

# %%
# to check whether a number is positive negative or zero

num=int(input("enter 1st no."))
if num > 0:
     print('positive')
elif num==0:
    print('zero')
else:
    print('negative')
# Out:
# enter 1st no. 2
# positive

# %%
# ceck if the number is odd or even
num=int(input("enter the no."))
if num % 2==0:
    print('even')
else:
    print('odd')
# Out:
# enter the no. 3
# odd

# %%
int(True)
# Out:
# 1

# %%
int(False)
# Out:
# 0

# %%
True+True+False
# Out:
# 2

# %%
### check id number is in between 50 and 100 or not (use nested if )
num=int(input("enter the id"))
if num>50:
    if num<100:
        print("condition accepted")
    else:
        print("greater then 50 and less then 100")
else:
    print("number is less than 50")
# Out:
# enter the id 67
# condition accepted

# %%
#do the same with logical operator
num=int(input("enter the no"))
if num>=50 and num <=100:
    print("satisfied")
else:
    print("not satisfied")
# Out:
# enter the no 2
# not satisfied

# %%
#read purchase cost and selling cost from the user
#state profit or loss and how much
selling_price=int(input("enter the selling_cost"))
purchase_price=int(input("enter the purchasing_cost"))
if selling_price>purchase_price:
    price(f"profit of=> {selling_price - purchase_price}")
else:
    print(f"lost of=> {purchase_price-selling_price} and ur time")
# Out:
# enter the selling_cost 2311
# enter the purchasing_cost 2465
# lost of=> 154 and ur time

# %%
year=int(input("enter year"))
if year%4==0:
    if year%400==0:
        print("leap year")
    else:
         print("not a leap year")
else:
     print("century but not a leap year")
# Out:
# enter year 2024
# not a leap year

# %%
print("welcome to simple calculator")
num=int(input("enter the number"))
print("menu=>\n1.Square\n2.cube\n3.check +ve or -ve")
ch=int(input("select ur choice"))
if ch==1:
    print(num*num)
elif ch==2:
    print(num ** 3)
elif ch==3:
      if num > 0:
         print("positive")
 
 
else:
    print("pagal hai kya be thik se choose kr")
# Out:
# welcome to simple calculator
# enter the number 2
# menu=>
# 1.Square
# 2.cube
# 3.check +ve or -ve
# select ur choice 2
# 8

# %%
#take a string from user menu->upper, lower, replace a particular part of a string for the 3rd part it should which part to replace with what
name="PYTHON"
print("hello this is our string enter your choice")
print("menu-> \n1.Uppercase\n2.Lowercase\n3.replace")
ch=int(input("select your choice"))
if ch==1:
    print(name.upper())
elif ch==2:
    print(name.lower())
elif ch==3:
    mn=input("which number character you want to replace")
    nm=input("by which character u want to replace")
    new= name.replace(mn, nm)
    print(f"result->{new}")
# Out:
# hello this is our string enter your choice
# menu->
# 1.Uppercase
# 2.Lowercase
# 3.replace
# select your choice 3
# which number character you want to replace y
# by which character u want to replace d
# result->PYTHON
