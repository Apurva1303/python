# %%
Name="Apurva"
Name
# Out:
# 'Apurva'

# %%
Name.lower()
# Out:
# 'apurva'

# %%
Name.upper()
# Out:
# 'APURVA'

# %%
St1="Apu"

# %%
St1.title()
# Out:
# 'Apu'

# %%
St1.swapcase()
# Out:
# 'aPU'

# %%
St1.islower()
# Out:
# False

# %% [markdown]
# St1.isupper()

# %%
St1.isupper()
# Out:
# False

# %%
name1="ok"
name2="123"
name3="ok123"

# %%
name1.isalpha()
# Out:
# True

# %%
name2.isalpha()
# Out:
# False

# %%
name1.isdigit()
# Out:
# False

# %%
name2.isdigit()
# Out:
# True

# %%
name1.isalnum()
# Out:
# True

# %%
name2.isalnum()
# Out:
# True

# %%
s8="Sukanya"
s8
# Out:
# 'Sukanya'

# %%
s8.startswith("S")
# Out:
# True

# %%
s8.endswith("A")
# Out:
# False

# %%
s8.endswith("kanya")
# Out:
# True

# %%
s8.startswith("kanya")
# Out:
# False

# %%
s8.lstrip()
# Out:
# 'Sukanya'

# %%
s8.rstrip()
# Out:
# 'Sukanya'

# %%
len(s8)
# Out:
# 7

# %%
s8.replace('S','A')
# Out:
# 'Aukanya'

# %%
s8.replace('k', ' ')
# Out:
# 'Su anya'

# %% [markdown]
# Operators
# =====

# %%
#Arithmetic operators
a=5
b=17

# %%
a+b
# Out:
# 22

# %%
a-b
# Out:
# -12

# %%
a*b
# Out:
# 85

# %%
a%b
# Out:
# 5

# %%
a/b
# Out:
# 0.29411764705882354

# %%
a//b#floor div
# Out:
# 0

# %%
b%a
# Out:
# 2

# %%
#assignment operators

# %%
z=5
z
# Out:
# 5

# %%
z=z+3
z
# Out:
# 11

# %%
z=11

# %%
z*=3
z
# Out:
# 99

# %%
z*=2
z
# Out:
# 396

# %% [raw]
# #comparision operator

# %%
a=2
b=3

# %%
a*b
# Out:
# 6

# %%
a==b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
b>a
# Out:
# True

# %%
#logical  operator

# %%
z=2
y=3

# %%
print(z>y or y>z)
# Out:
# True

# %%
print(z>y or z>y)
# Out:
# False

# %%
print (not(z>10))
# Out:
# True

# %%
not y
# Out:
# False

# %%
not z
# Out:
# False

# %%
#identity operator->is, is not

# %%
s=5
d=5

# %%
id(s),id(d)
# Out:
# (140723739206696, 140723739206696)

# %%
s is d
# Out:
# True

# %%
a=[3,4]
d=[3,4]

# %%
id(a)
# Out:
# 1500304247616

# %%
id(d)
# Out:
# 1500305021632

# %%
a is d
# Out:
# False

# %%
a is not d
# Out:
# True

# %%
z=a

# %%
z is a
# Out:
# True

# %%
z
# Out:
# [3, 4]

# %%
a.append(5)
a
# Out:
# [3, 4, 5, 5]

# %%
z
# Out:
# [3, 4, 5, 5]

# %%
#membership operator

# %%
l=[2,4,6,7,8,9]

# %%
6 in l
# Out:
# True

# %%
2 in l
# Out:
# True

# %%
0 in l
# Out:
# False

# %% [markdown]
# Precedence and association
# ====

# %%
#BODOMAS rule

# %%
5+2-10
# Out:
# -3

# %%
(4-2)**2
# Out:
# 4

# %%
2**2**3 #right hand assocation
# Out:
# 256

# %%
2**3/2
# Out:
# 4.0

# %%
2**3//2
# Out:
# 4

# %%
#print function

# %%
name = "Apurva"

# %%
marks = 87.60

# %%
# my name is Apurva and marks are 87.60

# %%
print("my name is",name "and my marks are",marks)
# Out:
#   Cell In[111], line 1
#     print("my name is",name "and my marks are",marks)
#                             ^
# SyntaxError: invalid syntax

# %%
print("my name is",name,"and my marks are",marks)
# Out:
# my name is Apurva and my marks are 87.6

# %%
print("my name is %s and marks are %f"%(name,marks))
# Out:
# my name is Apurva and marks are 87.600000

# %%
print(f "my name is {name}and marks are{marks}") #space not allowed near f
# Out:
#   Cell In[114], line 1
#     print(f "my name is {name}and marks are{marks}") #space not allowed near f
#             ^
# SyntaxError: invalid syntax

# %%
print(f"my name is {name} and marks are {marks}")
# Out:
# my name is Apurva and marks are 87.6

# %%
#ascii

# %%
ord("a")
# Out:
# 97

# %%
ord("s")
# Out:
# 115

# %%
chr(64)
# Out:
# '@'

# %%
chr(31)
# Out:
# '\x1f'

# %%
#type casting

# %%
num1=34
num2=44.56
num3="ok"

# %%
type(num1)
# Out:
# int

# %%
float(num2)
# Out:
# 44.56

# %%
str(num1)
# Out:
# '34'

# %%
#user input

# %%
a=input("enter namee or number")
# Out:
# enter namee or number apurva1303

# %%
a=input("enter a number")
# Out:
# enter a number Apurva

# %%
print("ok")
# Out:
# ok

# %%
# writing program for addition of two number using user input

# %%
a =int(input("enter a "))
b= int(input("enter b "))
z=a+b
print("Addition is ",z)
# Out:
# enter a  2
# enter b  4
# Addition is  6

# %%
# read the time time in seconds as user input AND print the time in the format as 
#as hour:minutes:second

# %%
seconds=int(input("enter time in second:="))
hours = seconds // 3600
minutes = (seconds % 3600) // 60
seconds = seconds % 60
print("hour:",hours,"minutes:",minutes,"seconds",seconds)
# Out:
# enter time in second:= 40002
# hour: 11 minutes: 6 seconds 42
