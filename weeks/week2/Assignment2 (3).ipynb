# %% [markdown]
# python weekly assignments 2
# ====

# %% [markdown]
# 1. Write a function analyze_sentence(sentence) that takes a sentence and returns a dictionary with
# word_count,
# char_count (excluding spaces),
# unique_words (case-insensitive),
# and most_frequent_word.
#     Test it with:"The quick brown fox jumps over the lazy dog the fox"

# %%
def analyze_sentence(sentence):
    words = sentence.lower().split()

    return {
        "word_count": len(words),
        "char_count": len(sentence.replace(" ", "")),
        "unique_words": len(set(words)),
        "most_frequent_word": max(words, key=words.count)
    }

# %%
analyze_sentence("The quick brown fox jumps over the lazy dog the fox")
# Out:
# {'word_count': 11,
#  'char_count': 41,
#  'unique_words': 8,
#  'most_frequent_word': 'the'}

# %% [markdown]
# 2. Given the string below, do the following and print each result:
# text = "A man a plan a canal Panama"
# a) Reverse the string without using slicing.
# b) Check if it is a palindrome, ignoring case and spaces.
# c) Replace every vowel with *.
# d) Count how many times each vowel appears.

# %%
text = "A man a plan a canal Panama"

# a) Reverse the string
rev = ""
for i in text:
    rev = i + rev
print("Reverse:", rev)

# b) Palindrome check
s = text.replace(" ", "").lower()
r = ""
for i in s:
    r = i + r
print("Palindrome:", s == r)

# c) Replace vowels with *
new = ""
for i in text:
    if i.lower() in "aeiou":
        new += "*"
    else:
        new += i
print("After replacing vowels:", new)

# d) Count vowels
print("a:", text.lower().count("a"))
print("e:", text.lower().count("e"))
print("i:", text.lower().count("i"))
print("o:", text.lower().count("o"))
print("u:", text.lower().count("u"))
# Out:
# Reverse: amanaP lanac a nalp a nam A
# Palindrome: True
# After replacing vowels: * m*n * pl*n * c*n*l P*n*m*
# a: 10
# e: 0
# i: 0
# o: 0
# u: 0

# %%
3. Write a function format_report(data) that takes a list of tuples (name, score, grade) and prints a formatted table where
name is left-aligned (width 15), 
score is right-aligned (width 6),
and grade is centered (width 8).
    Use this data:data = [("Alice", 92, "A"), ("Bob", 78, "B+"), ("Charlie", 65, "C"), ("Diana", 100, "A+")]

# %%
def format_report(data):
    print(f"{'Name':<15}{'Score':>6}{'Grade':^8}")
  

    for name, score, grade in data:
        print(f"{name:<15}{score:>6}{grade:^8}")

data = [
    ("Alice", 92, "A"),
    ("Bob", 78, "B+"),
    ("Charlie", 65, "C"),
    ("Diana", 100, "A+")
]

format_report(data)
# Out:
# Name            Score Grade
# Alice              92   A
# Bob                78   B+
# Charlie            65   C
# Diana             100   A+

# %%
4. Write a function list_ops(nums) that:
a) Removes duplicates while preserving the original order.
b) Returns a new list with only elements at even indices, squared.
c) Flattens the nested list into a single list using list comprehension.nums = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3] nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]

# %%
def list_ops(nums, nested):

 
    unique = []
    for num in nums:
        if num not in unique:
            unique.append(num)


    squared_even = [nums[i]**2 for i in range(0, len(nums), 2)]


    flat = [item for sublist in nested for item in sublist]

    return unique, squared_even, flat


nums = [3, 1, 4, 1, 5, 9, 2, 6, 5, 3]
nested = [[1, 2, 3], [4, 5], [6, 7, 8, 9]]

unique, squared_even, flat = list_ops(nums, nested)

print("Without duplicates:", unique)
print("Even-index elements squared:", squared_even)
print("Flattened list:", flat)
# Out:
# Without duplicates: [3, 1, 4, 5, 9, 2, 6]
# Even-index elements squared: [9, 16, 25, 4, 25]
# Flattened list: [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# 5. Given the tuple below:
# employee = ("E042", "Riya Sharma", "Data Science", 72000, "Pune")
# a) Unpack it into meaningful variable names.
# b) Use * unpacking to separate the first element, the last, and everything in between.
# c) Write a function update_salary(emp_tuple, new_salary) that returns a new tuple with the salary updated.

# %%
employee = ("E042", "Riya Sharma", "Data Science", 72000, "Pune")

emp_id, name, department, salary, city = employee

print("Employee ID:", emp_id)
print("Name:", name)
print("Department:", department)
print("Salary:", salary)
print("City:", city)

first, *middle, last = employee

print("\nFirst element:", first)
print("Middle elements:", middle)
print("Last element:", last)

def update_salary(emp_tuple, new_salary):
    return emp_tuple[:3] + (new_salary,) + emp_tuple[4:]
# Out:
# Employee ID: E042
# Name: Riya Sharma
# Department: Data Science
# Salary: 72000
# City: Pune
#
# First element: E042
# Middle elements: ['Riya Sharma', 'Data Science', 72000]
# Last element: Pune

# %%
print("\nOriginal Tuple:", employee)
updated_employee = update_salary(employee, 80000)
print("Updated Tuple:", updated_employee)
# Out:
# Original Tuple: ('E042', 'Riya Sharma', 'Data Science', 72000, 'Pune')
# Updated Tuple: ('E042', 'Riya Sharma', 'Data Science', 80000, 'Pune')

# %% [markdown]
# 6. Using the sets below, find:
# batch_a = {"Aarav", "Priya", "Karan", "Meera", "Sahil"}
# batch_b = {"Karan", "Meera", "Tanvi", "Rohan"}
# batch_c = {"Priya", "Aarav"}
# a) Students present in both batches.
# b) Students in batch_a but not in batch_b.

# %%
batch_a = {"Aarav", "Priya", "Karan", "Meera", "Sahil"}
batch_b = {"Karan", "Meera", "Tanvi", "Rohan"}

common_students = batch_a & batch_b
only_in_a = batch_a - batch_b

print("Students present in both batches:", common_students)
print("Students only in batch_a:", only_in_a)
# Out:
# Students present in both batches: {'Meera', 'Karan'}
# Students only in batch_a: {'Sahil', 'Aarav', 'Priya'}

# %% [markdown]
# 7.Write a function inventory_manager(records) that takes a list of tuples
# (product, category, quantity, price) and returns a dictionary grouped by category.
#
# Each category should have:
# - total_items
# - total_value
# - a list of product names
#
# Use:
#
# records = [
#     ("Laptop", "Electronics", 10, 55000),
#     ("Mouse", "Electronics", 50, 499),
#     ("Desk", "Furniture", 8, 12000),
#     ("Chair", "Furniture", 15, 4500),
#     ("Pen", "Stationery", 200, 20)
# ]

# %%
def inventory_manager(records):
    inventory = {}

    for product, category, quantity, price in records:

        if category not in inventory:
            inventory[category] = {
                "total_items": 0,
                "total_value": 0,
                "products": []
            }

        inventory[category]["total_items"] += quantity
        inventory[category]["total_value"] += quantity * price
        inventory[category]["products"].append(product)

    return inventory

# %%
records = [
    ("Laptop", "Electronics", 10, 55000),
    ("Mouse", "Electronics", 50, 499),
    ("Desk", "Furniture", 8, 12000),
    ("Chair", "Furniture", 15, 4500),
    ("Pen", "Stationery", 200, 20)
]

result = inventory_manager(records)

for category, details in result.items():
    print(category, ":", details)
# Out:
# Electronics : {'total_items': 60, 'total_value': 574950, 'products': ['Laptop', 'Mouse']}
# Furniture : {'total_items': 23, 'total_value': 163500, 'products': ['Desk', 'Chair']}
# Stationery : {'total_items': 200, 'total_value': 4000, 'products': ['Pen']}

# %%
8. Implement the following:
a.A function power_all(*args, exp=2) that returns a list of each number raised to exp.
b.A function profile(**kwargs) that prints each key-value pair as Key : Value.
c.Use a lambda inside sorted() to sort the list of dicts below by cgpa in descending order.
    students = [{"name": "Arjun", "cgpa": 8.4}, {"name": "Sanya", "cgpa": 9.1}, {"name": "Dev", "cgpa": 7.8}]

# %%
def power_all(*args, exp=2):
    result = []

    for i in args:
        result.append(i ** exp)

    return result

print(power_all(2, 3, 4))
# Out:
# [4, 9, 16]

# %%
# b) profile(**kwargs)

def profile(**kwargs):
    for key, value in kwargs.items():
        print(key, ":", value)
profile(name="Apurva", age=19, city="Pune")
# Out:
# name : Apurva
# age : 19
# city : Pune

# %%
# c) Sort by cgpa in descending order
students = [
    {"name": "Arjun", "cgpa": 8.4},
    {"name": "Sanya", "cgpa": 9.1},
    {"name": "Dev", "cgpa": 7.8}
]

sorted_students = sorted(
    students,
    key=lambda x: x["cgpa"],
    reverse=True
)

print(sorted_students)
# Out:
# [{'name': 'Sanya', 'cgpa': 9.1}, {'name': 'Arjun', 'cgpa': 8.4}, {'name': 'Dev', 'cgpa': 7.8}]

# %%
9. Create a module stats_utils.py with three functions:
a) mean(data) — arithmetic mean.
b) variance(data) — population variance without using the statistics module.
c) normalize(data) — min-max normalization returning values between 0 and 1.
In a separate main.py, import and use these functions on the dataset below. Also compute the
standard deviation using the math module.
dataset = [12, 45, 7, 23, 56, 89, 34, 67, 11, 90]

# %%
# %%writefile stats_utils.py
def mean(data):
    return sum(data) / len(data)

def variance(data):
    avg = mean(data)

    total = 0
    for x in data:
        total += (x - avg) ** 2

    return total / len(data)      # Population variance

def normalize(data):
    min_val = min(data)
    max_val = max(data)

    normalized = []
    for x in data:
        norm = (x - min_val) / (max_val - min_val)
        normalized.append(norm)

    return normalized
# Out:
# Writing stats_utils.py

# %%
import math
from stats_utils import mean, variance, normalize

dataset = [12, 45, 7, 23, 56, 89, 34, 67, 11, 90]

avg = mean(dataset)
var = variance(dataset)
std_dev = math.sqrt(var)
norm_data = normalize(dataset)

print("Dataset:", dataset)
print("Mean:", avg)
print("Variance:", var)
print("Standard Deviation:", std_dev)
print("Normalized Data:", norm_data)
# Out:
# Dataset: [12, 45, 7, 23, 56, 89, 34, 67, 11, 90]
# Mean: 43.4
# Variance: 883.4399999999999
# Standard Deviation: 29.722718583602003
# Normalized Data: [0.060240963855421686, 0.4578313253012048, 0.0, 0.1927710843373494, 0.5903614457831325, 0.9879518072289156, 0.3253012048192771, 0.7228915662650602, 0.04819277108433735, 1.0]

# %%
#a
def make_multiplier(n):
    def multiplier(x):
        return x * n
    return multiplier

# Creating functions
triple = make_multiplier(3)
quintuple = make_multiplier(5)

print("Triple of 10 =", triple(10))
print("Quintuple of 10 =", quintuple(10))
# Out:
# Triple of 10 = 30
# Quintuple of 10 = 50

# %%
# B
import time

def timer(func):
    def wrapper(*args, **kwargs):
        start = time.time()

        result = func(*args, **kwargs)

        end = time.time()
        print("Execution Time:", end - start, "seconds")
        return result
    return wrapper

@timer
def slow_sum(n):
    total = 0
    for i in range(1, n + 1):
        total += i ** 2
    return total

print("Sum =", slow_sum(100000))
# Out:
# Execution Time: 0.025870561599731445 seconds
# Sum = 333338333350000

# %%
#c
import math

def validate_positive(func):
    def wrapper(*args, **kwargs):
        for arg in args:
            if arg <= 0:
                raise ValueError("Arguments must be positive")

        return func(*args, **kwargs)
    return wrapper

@validate_positive
def safe_sqrt(x):
    return math.sqrt(x)

print(safe_sqrt(25))

# Test with invalid value
print(safe_sqrt(9))
# Out:
# 5.0
# 3.0
