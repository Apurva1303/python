# %%
create a class called student 
create 2-3 objects having attributes name,age
create a method which will addd a skill(eg python,ml,java)to the student
where u can view the info it later(i.e. skills learned by student)

# %%
class Student:
    def __init__(self,name,age):
        self.name=name
        self.age=age
        self.skills=[]
    def add_skill(self,skill):
        print("Add a new skill")
        return self.skills.append(skill)

# %%
s1=Student('Apurva',18)

# %%
s1.add_skill('java')
# Out:
# Add a new skill

# %%
s1.skills
# Out:
# ['java']

# %% [markdown]
# Inheritance
# =====

# %%
class Person:
    insti="mitu"
    def __init__(self,age,ht):
        self.age=age
        self.ht=ht
    def show(self):
        print(f"age-> {self.age},height->{self.ht},institute->{self.insti}")

# %%
class Apu(Person):
    def __init__(self,age,ht,sal):
        super().__init__(age,ht)
        self.sal=sal
    def show_sal(self):
        print(f"salaray is {self.sal}")

# %%
a=Apu(25,5.8,34567)

# %%
a.show_sal()
# Out:
# salaray is 34567

# %%
a.show()
# Out:
# age-> 25,height->5.8,institute->mitu

# %% [markdown]
# Polymorphism
# ====

# %%
can be achived by method overriding

# %%
class Animal:
    def speak(self):
        return "sound of animal"

# %%
class Dog(Animal):
    def speak(self):
        return "woof!!!"

class Cat(Animal):
    def speak(self):
        return "meoww!!"

# %%
d=Dog()
c=Cat()

# %%
d.speak()
# Out:
# 'woof!!!'

# %%
c.speak()
# Out:
# 'meoww!!'

# %%
# simple meu driven with oop

# %%
#add items, view, exit (shopping list,grocery list)

# %%
class Menuapp:
    def __intii__(self):
        self.itemlist=[]
    def show_menu(self):
        print("Meu\n 1.add items\n 2.viwe item \n 3.exit")
        
    def add_items(self):
        item= input("enter the item name")
        self.itemlist.append(item)
    def view_items(self):
        return self.itemlist
    def run(self):
        while True:
            self.show_menu()
            ch=int(input("enter the choice"))
            if ch==1:
                self.add_items()
            elif ch==2:
                self.view_items()
            elif ch==3:
                break
            else:
                return 'invlid choice'

# %%
atharav=Menuapp()

# %%
atharav.run()
# Out:
# Meu
#  1.add items
#  2.viwe item
#  3.exit

# %%
#encapsulation with getter and setter

# %%
class Person:
    def __init__(self,age,name):
        self.__age=age
        self.__name=name

    #getter
    def get_name(self):
        return self.__name
    def get_age(self):
        return self.__age

    #setter
    def set_age(self,age):
        self.__age=age

# %%
p=Person(18,'Sukanya')

# %%
p.get_name()
# Out:
# 'Sukanya'

# %%
p.get_age()
# Out:
# 18

# %%
#dundar methods/ magic methods

# %%
dir(p)
# Out:
# ['_Person__age',
#  '_Person__name',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'get_age',
#  'get_name',
#  'set_age']

# %%
class Person:
    def __init__(self,age,name):
        self.__age=age
        self.__name=name

    #getter
    def get_name(self):
        return self.__name
    def get_age(self):
        return self.__age

    #setter
    def set_age(self,age):
        self.__age=age
    def __str__(self):
        return f"age -> {self.__age}, name=> {self.__name}"

# %%
p=Person(18,'Sukanya')

# %%
print(p)
# Out:
# age -> 18, name=> Sukanya

# %%
#decoraters

# %%
#create a menu driven appp for banking simulation
#cgheck balance,deposit money, withdraw money (you can add more things as u see fit to make the app better)

# %%
class BankAccount:
    def __init__(self, name, age, acc_no, balance=0):
        self.name = name
        self.age = age
        self.acc_no = acc_no
        self.balance = balance

    def display_details(self):
        print("\n--- Account Details ---")
        print("Name:", self.name)
        print("Age:", self.age)
        print("Account Number:", self.acc_no)
        print("Balance:", self.balance)

    def check_balance(self):
        print("Current Balance =", self.balance)

    def deposit(self):
        amount = float(input("Enter amount to deposit: "))
        self.balance += amount
        print("₹", amount, "deposited successfully.")

    def withdraw(self):
        amount = float(input("Enter amount to withdraw: "))
        if amount <= self.balance:
            self.balance -= amount
            print("₹", amount, "withdrawn successfully.")
        else:
            print("Insufficient balance!")

# Creating account
name = input("Enter Name: ")
age = int(input("Enter Age: "))
acc_no = input("Enter Account Number: ")

account = BankAccount(name, age, acc_no)

while True:
    print("\n===== BANK MENU =====")
    print("1. Display Account Details")
    print("2. Check Balance")
    print("3. Deposit Money")
    print("4. Withdraw Money")
    print("5. Exit")

    choice = input("Enter your choice: ")

    if choice == "1":
        account.display_details()

    elif choice == "2":
        account.check_balance()

    elif choice == "3":
        account.deposit()

    elif choice == "4":
        account.withdraw()

    elif choice == "5":
        print("Thank you for using the banking system!")
        break

    else:
        print("Invalid choice!")
# Out:
# Enter Name:  Apurva
# Enter Age:  18
# Enter Account Number:  997084
# ===== BANK MENU =====
# 1. Display Account Details
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  1
# --- Account Details ---
# Name: Apurva
# Age: 18
# Account Number: 997084
# Balance: 0
#
# ===== BANK MENU =====
# 1. Display Account Details
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  2
# Current Balance = 0
#
# ===== BANK MENU =====
# 1. Display Account Details
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  3
# Enter amount to deposit:  30000
# ₹ 30000.0 deposited successfully.
#
# ===== BANK MENU =====
# 1. Display Account Details
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
# Enter your choice:  2
# Current Balance = 30000.0
#
# ===== BANK MENU =====
# 1. Display Account Details
# 2. Check Balance
# 3. Deposit Money
# 4. Withdraw Money
# 5. Exit
